# %% [markdown]
# <head>
#     <style>
# p {
#   color : #000000;
#   font-family : 'arial';
#   line-height: 1.5em;
# }
# li {
#   color : #000000;
#   font-family : 'arial';
#   line-height: 1.5em;
# }
# h1 {
#   color : #000000;
#   text-align : center;
#   font-family: 'times new roman', times;
# }
# h2 {
#   color : #000000;
#   font-family: 'times new roman', times;
# }
# h3 {
#   color : #000000;
#   font-family: 'times new roman', times;
# }
# h4 {
#   color : #000000;
#   font-family: 'times new roman', times;
# }
# .step {
#   color : #000000;
#   font-family: 'times new roman', times;
#   font-style : italic;
#   font-weight : bold;
#   text-indent : 2em;
#   line-height: 1.5em;
# }
# .math {
#   color : #000000;
#   text-indent : 200px;
# }
# div.rblock {
#   float: right;
#   border: 1px solid gray;
#   text-align: center;
#   padding: 10px;
#   margin: 0 0 20px 20px;
# }
# span {
#   color: navy;
# }
# </style>
# </head>
#
# <h1> MAPR 2451: </br> Tight-Binding Exercises
# <hr>
# <h2> Part 1: </br> The tight-binding approximation </h2>
#
# <p>
#     The <a target="_tab" href=http://en.wikipedia.org/wiki/Tight_binding> tight binding</a> approximation is a method to calculate the electronic structure of condensed matter systems using linear combination of atomic orbitals to represent the electronic wavefunctions. Most often, the elements of the tight binding hamiltonian are not computed directly but are rather fitted on data from other sources (experiments or more advanced calculations). In many situations, the resulting model provides qualitative results at a very low computational cost compared with first-principles methods.
# </p>
#
# <h3 style="color:#0B69A5;">
#     Linear combination of atomic orbitals
# </h3>
# <p>
#     In order to derive the electronic spectrum of a quantum mechanical system, one has to solve the corresponding time-independent<a target="_tab" href=http://en.wikipedia.org/wiki/Schr%C3%B6dinger_equation> Schroedinger equation</a>,
# </p>
# <p class="math"> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $\hat{H}\, |\Psi \rangle= E \, |\Psi \rangle$, </p>
# <p>
#     where $\hat{H}$ is the <a target="_tab" href=http://en.wikipedia.org/wiki/Hamiltonian_%28quantum_mechanics%29> Hamiltonian </a> of the system. Within the tight binding approximation, the electronic wavefunctions $\Psi(\vec{r})$ are expanded as linear combinations of atomic orbitals $\{\phi(\vec{r})\}$,
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; $\Psi(\vec{r}) = \sum_{i,\alpha} \, c_{i}(\vec{R}_{\alpha}) \, \phi_{i}(\vec{r}-\vec{R}_{\alpha}) = \sum_{\mu} \, c_{\mu} \, \phi_{\mu}(\vec{r})$
# </p>
# <p>
#     Here, $i$ refers to the i$^{th}$ atomic energy level, and $\vec{R}_{\alpha}$ locates the atom $\alpha$ in the crystal lattice. Without loosing in generality, the second equality introduces a combined indice $\mu$ that indexes the $(\alpha, i)$ pairs.
# </p>
#
# <h3 style="color:#0B69A5;">
#     The translational symmetry of the crystal
# </h3>
# <p>
#     In the case of electrons in a periodic potential, we know that the electronic eigenstates are <a target="_tab" href=http://en.wikipedia.org/wiki/Bloch_theorem> Bloch functions</a> :
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\Psi(\vec{r}) = e^{i\vec{k}.\vec{r}}.u(\vec{r})$,
# </p>
# <p>
#     where $\vec{k}$ is the wavevector of the wavefunction and $u(\vec{r})$ has the periodicity of the potential. Hence, under translation over a lattice vector $\vec{R}_l$, the wave function only changes by a phase factor,
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\Psi(\vec{r}+\vec{R}_l) = e^{i\vec{k}.\vec{R}_l}\Psi(\vec{r})$ .
# </p>
# <p>
#     As a consequence, the coefficients $c(\vec{R}_{\mu})$ satisfy the relation,
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$c(\vec{R}_{\mu}+\vec{R}_{l}) = e^{i\vec{k}.\vec{R}_l} \, c(\vec{R}_{\mu})$,
# </p>
# <p>
#     and the electronic wavefunction can be conveniently rewritten as a finite sum over Bloch-like atomic orbitals,
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\Psi(\vec{r}) = \sum_{\mu_0} \, c_{\mu_0}(\vec{k}) \, \Phi_{\mu_0}(\vec{r},\vec{k}) $,
# </p>
# <p>
#     where,
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\Phi_{\mu_0}(\vec{r},\vec{k}) = \frac{1}{\sqrt{N}}\,\sum_{\mu' \equiv \mu_0}  e^{i\vec{k}.\vec{R}_{\mu'}} \phi(\vec{r}-\vec{R}_{\mu'}) $.
# </p>
# <p>
#     Here, $\mu_0$ refers to atomic orbitals contained within the unit cell and $\sum_{\mu'\equiv \mu_0}$ denotes a sum running over all the atomic orbitals that are equivalent to $\phi(\vec{r}-\vec{R}_{\mu_0})$ by means of lattice vector translations. The prefactor $1/\sqrt{N}$ has been introduced so as to normalize the Bloch-like atomic orbitals. $N$ denotes the number of unit cells in the crystal. The approximated electronic wavefunctions are now expressed in a way that naturally accounts for the translational symmetry of the crystal. Each electronic wavefunction is characterized by a specific wavevector $\vec{k}$. In what follows, we will denote $E_j(\vec{k})$ and $\Psi_j(\vec{k})$, the j$^{th}$ electronic energy level at wavevector $\vec{k}$ and its associated electronic eigenstate.
# </p>
#
# <h3 style="color:#0B69A5;">
#     The tight-binding Hamiltonian
# </h3>
# <p>The stationary states of a quantum mechanical systems are the solutions of the time-independent<a target="_tab" href=http://en.wikipedia.org/wiki/Schr%C3%B6dinger_equation> Schroedinger equation</a>,</p>
# <p class="math"> &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\hat{H}\, |\Psi_j(\vec{k}) \rangle = E_j(\vec{k})\, |\Psi_j(\vec{k})\rangle $ .</p>
# <p>
#     By substituting $\Psi_j(\vec{k})$ and projecting onto the set of Bloch-like atomic orbitals $\{ \Phi_{\mu_0}(\vec{k})\}$, one gets a <a target="_tab" href=http://en.wikipedia.org/wiki/Eigendecomposition_of_a_matrix#Generalized_eigenvalue_problem> generalized eigenvalue equation </a> that uniquely determines the expansion coefficients $\{ c_{j,\mu_0}(\vec{k}) \}$ of the electronic eigenstates characterized by the wavevector $\vec{k}$:
# </p>
# <p class="step">
#     (a) Substitution :
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$ \frac{1}{\sqrt{N}} \,\sum_{\mu_0} \, c_{j,\mu_0}(\vec{k}) \, \hat{H}\,| \Phi_{\mu_0} \rangle = E_j(\vec{k})\, \frac{1}{\sqrt{N}} \,\sum_{\mu_0} \, c_{j,\mu_0}(\vec{k}) \, |\Phi_{\mu_0} \rangle$
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$ \frac{1}{\sqrt{N}} \,\sum_{\mu_0} \, c_{j,\mu_0}(\vec{k}) \, \sum_{\mu' \equiv \mu_0}  e^{i\vec{k}.\vec{R}_{\mu'}}\, \hat{H}\,| \phi_{\mu'} \rangle = E_j(\vec{k})\, \frac{1}{\sqrt{N}} \,\sum_{\mu_0} \, c_{j,\mu_0}(\vec{k}) \, \sum_{\mu' \equiv \mu_0}  e^{i\vec{k}.\vec{R}_{\mu'}}\, | \phi_{\mu'}\rangle$
# </p>
# <p class="step">
#     (b) Projection :
# </p>
# <p class="math">
#     $\frac{1}{N} \, \sum_{\mu_0} \, c_{j,\mu_0}(\vec{k}) \,  \sum_{(\nu' \equiv \nu_0, \mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu'})}\, \langle \phi_{\nu'}\, | \hat{H}\,| \phi_{\mu'} \rangle = E_j(\vec{k})\, \frac{1}{N} \,\sum_{\mu_0} \, c_{j,\mu_0}(\vec{k}) \, \sum_{(\nu' \equiv \nu_0, \mu' \equiv \mu_0)}\, e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu'})}  \, \langle \phi_{\nu'}\, | \phi_{\mu'}\rangle$
# </p>
# <p class="step">
#     (c) Generalized eigenvalue equation :
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$H_{\nu_0 \mu_0}(\vec{k}) \, c_{j,\mu_0}(\vec{k}) = E_j(\vec{k})\, S_{\nu_0 \mu_0}\, c_{j,\mu_0}(\vec{k})$
# </p>
# <p class="step">
#     with
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$H_{\nu_0 \mu_0}(\vec{k}) = \langle \Phi_{\nu_0}(\vec{r},\vec{k}) |\hat{H} | \Phi_{\mu_0}(\vec{r},\vec{k}) \rangle = \frac{1}{N} \,
#     \sum_{(\nu' \equiv \nu_0, \mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu'})}\, \langle \phi_{\nu'}\, | \hat{H}\,| \phi_{\mu'} =
#     \sum_{(\mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu_0})}\, \langle \phi_{\nu_0}\, | \hat{H}\,| \phi_{\mu'}\rangle $
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$S_{\nu_0 \mu_0}(\vec{k}) = \langle \Phi_{\nu_0}(\vec{r},\vec{k}) | \Phi_{\mu_0}(\vec{r},\vec{k}) \rangle = \frac{1}{N} \,
#     \sum_{(\nu' \equiv \nu_0, \mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu'})}\, \langle \phi_{\nu'}\,| \phi_{\mu'} \rangle =
#     \sum_{(\mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu_0})}\, \langle \phi_{\nu_0}\,| \phi_{\mu'} \rangle
#     $
# </p>
#
# <p>
#    If we assume that the atomic orbitals $\{ \phi_{\mu}(\vec{r})\}$ are orthogonal, the equation further simplifies to the <a target="_tab" href=http://en.wikipedia.org/wiki/Eigenvalues_and_eigenvectors> eigenvalue problem </a>:
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$H_{\nu_0 \mu_0}(\vec{k}) \, c_{j,\mu_0}(\vec{k}) = E_j(\vec{k})\, c_{j,\mu_0}(\vec{k})$
# </p>
# <p>
#     Solving this equation for a given wavevector $\vec{k}$ provides the energies and the expansion coefficients of the electronic wavefunctions $\Psi_j(\vec{k})$. Solving the equation for all the wavevectors within the first <a target="_tab" href=http://en.wikipedia.org/wiki/Brillouin_zone> Brillouin zone </a> fully determines the tight binding <a target="_tab" href=http://en.wikipedia.org/wiki/Electronic_band_structure> band structure </a> of the crystal.
# </p>
#
# <h3 style="color:#0B69A5;">
#     Common approximations
# </h3>
#
# <p>
#     The elements of the TB hamiltonian matrice  have the general form :
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$H_{\nu_0 \mu_0}(\vec{k}) =
#     \sum_{(\mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu_0})}\, \langle \phi_{\nu_0}\, | \hat{H}\,| \phi_{\mu'}\rangle =
#     \sum_{(\mu' \equiv \mu_0)}\,  e^{i\vec{k}.(\vec{R}_{\mu'}-\vec{R}_{\nu_0})}\, \langle \phi_{\nu_0}\, | \sum_{\alpha} \left(\hat{H}^0_{\alpha} + \Delta\hat{U}_{\alpha} \right)\,| \phi_{\mu'}\rangle $
# </p>
# <p>
#     Here, $\hat{H}^0_{\alpha}$ is the Hamiltonian of the isolated atom $\alpha$ and $\Delta\hat{U}_{\alpha}$ is the modification of the atomic Hamiltonian induced by the crystal. The diagonal elements of the tight binding Hamiltonian are commonly named the "on-site energies" as they set the energy reference of the calculation. The out-of-diagonal elements are commonly called the "hopping integrals" as they are related to the probility of an electron to "jump" between sites. In practice, the matrice elements are not directly computed as we do not know a priori the operator $\Delta\hat{U}_{\alpha}$. A common strategy is to select the elements $\langle \phi_{\nu_0}\, | \hat{H}\,| \phi_{\mu'}\rangle$ that contribute most significantly to the TB hamiltonian and to fit their values either on experimental data or on theoretical band structure calculations from other sources.
# </p>
# <p>
#     A widely used approach consists in considering only the interactions between neighbouring lattice sites. In this scheme, the simplest model is obtained by including only the interaction between the nearest-neighbours. If needed, the quality of the model can then be improved by progressively increasing the number of neighbours entering the hamiltonian (second nearest-neighbours, third nearest-neighbours, and so on).
# </p>
#
# <h3 style="color:#0B69A5;">
#     Translational symmetry in reciprocal space
# </h3>
#
#
# <p>
#     From the <a target="_tab" href=http://en.wikipedia.org/wiki/Bloch_wave> Bloch theorem </a>, we know that the eigenstates of an electron in a periodic potential can be written as Bloch waves:
# </p>
# <p class="math">
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$\Psi(\vec{r}) = e^{i\vec{k}.\vec{r}}.u(\vec{r})$.
# </p>
#
# <div class="rblock">
#     <img align='right' src='https://upload.wikimedia.org/wikipedia/commons/5/56/BlochWaves1D.svg' height="400" width="400">
# </div>
#
# <p>
#     It is important to realize that if $\Psi(\vec{r})$ can be written using wavevector $\vec{k}$, it an be equivalently reprenseted by the wavevector $\vec{k}+\vec{K}$, where $\vec{K}$ is any <a target="_tab" href=http://en.wikipedia.org/wiki/Reciprocal_lattice> reciprocal lattice vector </a>. This is represented in Fig. 1. A Bloch wave (bottom) can be broken up into the product of a periodic function (top) and a plane-wave (center). The left side and right side represent the same Bloch wave broken up in two different ways, involving the wave vector $\vec{k}_1$ (left) or $\vec{k}_2$ (right). The difference $\vec{k}_1-\vec{k}_2$ is a reciprocal lattice vector. In all plots, blue is real part and red is imaginary part.
# </p>
#
#
#
# <p>
#     Therefore, wavevectors whose difference corresponds to a reciprocal lattice vector are equivalent in the sense that they characterize the same subset of <a target="_tab" href=http://en.wikipedia.org/wiki/Bloch_wave> Bloch states </a>. To fully characterize the electronic band structure of a system, one can thus restrict the study to the wavevectors contained in the first <a target="_tab" href=http://en.wikipedia.org/wiki/Brillouin_zone> Brillouin zone</a> (i.e. the primitive cell of the reciprocal space that lies bewteen the <a target="_tab" href=http://en.wikipedia.org/wiki/Bragg_plane> Bragg planes </a>). By sake of convenience, the electronic band structure of crystals are often depicted along predefined paths within the first <a target="_tab" href=http://en.wikipedia.org/wiki/Brillouin_zone> Brillouin zone</a>. Commonly those paths are made of line segments connecting the point of symmetry in reciprocal space.
# </p>

# %% [markdown]
# <hr />
# <h2> Part 2: </br> An example, the tight-binding model of graphene</h2>
#
# <p>
#
# <div class="rblock">
#     <img align='right' src='pics/graphene_structure.png' height="400" width="350"> <br>
# </div>
#
# <a target="_tab" href=http://en.wikipedia.org/wiki/Graphene> Graphene </a> is the two-dimensional allotropic form of carbon in which atoms are arranged in an hexagonal network. The  stability of the lattice is due to the strong  bond that forms in between the $sp^2$ hybridized carbon atoms. The $2s$, $2p_x$, $2p_y$ atomic orbitals of carbon take part in this hybridization process and are responsible for the $c$-$c$ $\sigma$-bonds. The eigenenergies of the associated bonding and anti-bonding bands lie far away from the <a target="_tab" href=http://en.wikipedia.org/wiki/Fermi_energy> Fermi level </a>, ($\delta E>3$eV). The low energy properties of graphene (e.g. its ultra-high electron mobility, its optical properties, etc...) are ruled by the remaining $2p_z$ atomic orbital of carbon that forms highly delocalized $\pi$-bonds. The separation of the energy range associated with the $\sigma$ and $\pi$ bands allows to describe the low energy physics of graphene with the $p_z$ atomic orbitals only. In what follows, we derive tight-binding model of graphene within the so-called $\pi$-band approximation.
# </p>
#
#
#
#
# <h3 style="color:#0B69A5;">The basis set :</h3>
# <p>
#     Let us consider the smallest basis set of atomic orbitals for the description of the low-energy electronic states in graphene. It consists of two carbon $p_z$ orbitals centered on the atoms A and B of the graphene unit-cell ${\phi(\vec{r}-\vec{R}_{A}), \phi(\vec{r}-\vec{R}_{A})}$. The Bloch-like atomic orbitals are then given by:
# </p>
# <p class="math">
#     $\Phi_A(\vec{k}) = \frac{1}{\sqrt{N}} \sum_{R_{A}}{} e^{i \vec{k} \cdot (\vec{r}-\vec{R}_{A})} \phi(\vec{r}-\vec{R}_{A})$
# </p>
# <p class="math">
#     $\Phi_B(\vec{k}) = \frac{1}{\sqrt{N}} \sum_{R_{B}}{} e^{i \vec{k} \cdot (\vec{r}-\vec{R}_{B})} \phi(\vec{r}-\vec{R}_{B})$
# </p>
# <p>
#     The problem then reduces to the diagonalization of the following matrix:
# </p>
# <p class="math">
#     $\left( \begin{array}{cc}
#     \langle \Phi_A(\vec{k}) | \hat{H} | \Phi_A(\vec{k}) \rangle & \langle \Phi_A(\vec{k}) | \hat{H} | \Phi_B(\vec{k}) \rangle \\
#     \langle \Phi_B(\vec{k}) | \hat{H} | \Phi_A(\vec{k}) \rangle & \langle \Phi_B(\vec{k}) | \hat{H} | \Phi_B(\vec{k}) \rangle
#     \end{array}\right)$ .
# </p>
#
#
# <div class="rblock">
#     <img align='right' src='pics/graphene_band_structure.png' height="262" width="320"> <br>
# </div>
#
# <h3 style="color:#0B69A5;">The diagonal elements :</h3>
# <p>
#     If we consider only the interactions between first nearest neighbours, the on-site energies are given by:
# </p>
# <p class="math">
#     $\langle \Phi_A(\vec{k}) | \hat{H} | \Phi_A(\vec{k}) \rangle = \langle \phi(\vec{r}-\vec{R}_{A}) | \hat{H}  | \phi(\vec{r}-\vec{R}_{A})\rangle = \epsilon_A$ and
#     $\langle \Phi_B(\vec{k}) | \hat{H} | \Phi_B(\vec{k}) \rangle = \langle \phi(\vec{r}-\vec{R}_{B}) | \hat{H}  | \phi(\vec{r}-\vec{R}_{B})\rangle = \epsilon_B$ .
# </p>
# <p>
#     Accounting for the symmetry of the system, one defines:
# </p>
# <p class="math">
#     $\langle \phi(\vec{r}-\vec{R}_{A}) | \hat{H}  | \phi(\vec{r}-\vec{R}_{A})\rangle = \langle \phi(\vec{r}-\vec{R}_{B}) | \hat{H}  | \phi(\vec{r}-\vec{R}_{B})\rangle = \epsilon$ .
# </p>
# <h3 style="color:#0B69A5;">The off-diagonal elements :</h3>
# <p>
#     The hopping integrals are given by,
# </p>
# <p class="math">
#     $\langle \Phi_A(\vec{k}) | \hat{H} | \Phi_B(\vec{k}) \rangle = \sum_{j \in (1,2,3)} e^{i \vec{k}\cdot\vec{\delta_{j}}}\, \langle \phi(\vec{r}-\vec{R}_{A})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{A} -\vec{\delta}_{j}) \rangle $,
# </p>
# <p class="math">
#     $\langle \Phi_B(\vec{k}) | \hat{H} | \Phi_A(\vec{k}) \rangle = \sum_{j \in (1,2,3)} e^{i \vec{k}\cdot\vec{\delta_{j}}}\, \langle \phi(\vec{r}-\vec{R}_{B})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{B}) -\vec{\delta}_{j}\rangle $,
# </p>
# <p>
#     where $\delta_j$ with $j \in (1,2,3)$ are the vectors connecting a carbon atom to its nearest neighbours. Accounting for the symmetry of the system, one defines:
# </p>
# <p class="math">
#     $\langle \phi(\vec{r}-\vec{R}_{A})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{A}) -\vec{\delta}_{1}\rangle =
#     \langle \phi(\vec{r}-\vec{R}_{A})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{A}) -\vec{\delta}_{2}\rangle =
#     \langle \phi(\vec{r}-\vec{R}_{A})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{A}) -\vec{\delta}_{3}\rangle = t$
# </p>
# <p>
#     and,
# </p>
# <p class="math">
#     $\langle \phi(\vec{r}-\vec{R}_{B})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{B}) -\vec{\delta}_{1}\rangle =
#     \langle \phi(\vec{r}-\vec{R}_{B})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{B}) -\vec{\delta}_{2}\rangle =
#     \langle \phi(\vec{r}-\vec{R}_{B})\,| \hat{H} |\, \phi(\vec{r}-\vec{R}_{B}) -\vec{\delta}_{3}\rangle = t^{*}$ .
# </p>
#
#
# <h3 style="color:#0B69A5;">The tight-binding Hamiltonian :</h3>
# <p>
#     Eventually, the electronic band structure of graphene can be computed within the tight-binding approximation by diagonalizing the 2 by 2 matrix :
# </p>
# <p class="math">
#     $H^{TB}=\left( \begin{array}{cc}
#     \epsilon & t.f(\vec{k}) \\
#      t^*.f^*(\vec{k}) & \epsilon
#     \end{array}\right)$ ,
# </p>
# <p>
#     where we have introduce $f(\vec{k})$, defined as,
# </p>
# <p class="math">
#     $f(\vec{k}) = \sum_{j \in (1,2,3)} e^{i \vec{k}\cdot\vec{\delta_{j}}}$ .
# </p>
# <hr />

# %% [markdown]
# <h3>Exercise 2a: <br><br>
# Compute the band structure of graphene with one orbital per site</h3>
# <br>
# In this exercise we use the tight-binding approximation to compute the band structure of graphene. The tight-binding model that we use is very simple: we consider only one $p_z$ atomic orbital per carbon site and we restrict the interactions to the nearest-neighbours. We set the only parameter of the model, i.e. the hopping integral between neighbouring sites, to 2.6 eV. This value ensure a good agreement with experiments.
# <br><br>
# - What do you observe, is graphene metallic, semiconducting, or insulating?
# <br><br>
# - What happens if you modify the onsite energy? Can you explain why?

# %%
# Import the required python modules
import supertb as tb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(8,6)

### Define the atoms
# create a species using tb.NumericalAtom(label, symbol, [orbitals])
carbon = tb.NumericalAtom('C','C',orbs=['pz'])
# create a table of elements using tb.AtomicTable(species1,species2,...)
atomictable = tb.AtomicTable(carbon)           

### Build the structure
# create a lattice using tb.Lattice.from_parameters(a,b,c,alpha,beta,gamma)
lattice = tb.Lattice.from_parameters(2.46,2.46,20.,90.,90.,60.) 
# create a list of fractional coordinates
pos = [[0.,0.,0.],[1./3,1./3,0.]]  
# build the structure using tb.Structure(lattice, list_of_species, list_of_coordinates)
struct = tb.Structure(lattice, ['C','C'], pos, coords_are_cartesian=False) 

### Define the interatomic interactions
# from the structure build a graph charaterized by a cutoff radius
graph = tb.StructureGraph.init_from_structure(struct, 1.45)
# define the kind of tight-binding model
sk = tb.SlaterKosterParams(atomictable, spinpol=False, spinorb=False)
# set up the local tight-binding parameters
sk.set_local_integrals([('C', 0, 0, 1.)])
# set up the hopping parameters
sk.set_non_local_integrals([('C','C', 0, 0, 3, 2.6)])

### Set up the tight binding model 
egraph = tb.ElectronicStructure(graph, atomictable, H=sk)
# and compute the hamiltonian
egraph.compute_integrals('H')

### Plot the band structure
# Define the high-symmetry path in the Brillouin zone
kbands = [[0.,0.,0.],[0.5,0.,0.],\
          [0.5,0.,0.],[2./3.,1./3.,0.],\
          [2./3.,1./3.,0.],[0.,0.,0.]]
nkpts = [50,50,50]
# Diagonalize the hamiltonian at each k-point
bands = egraph.bands_structure(include=['H'], lines=kbands, nkpts=nkpts)
# Plot the bands structure
bands.plot_bands(xscale=True, klabels=['$\Gamma$','M','K','$\Gamma$'], \
                 vertices=[0,49,100,150], spincolors=['blue'],\
                 linestyle='-', emin=-8., emax=8.)

plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/pymatgen/core/__init__.py:49: UserWarning: Error loading .pmgrc.yaml: [Errno 2] No such file or directory: '/Users/sidubois/.pmgrc.yaml'. You may need to reconfigure your yaml file.
#   warnings.warn(f"Error loading .pmgrc.yaml: {ex}. You may need to reconfigure your yaml file.")
# /usr/local/lib/python3.9/site-packages/supertb/eigenset.py:671: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabels)

# %% [markdown]
# <h3>Exercise 2b: <br><br>Compute the band structure of graphene with four orbital per site</h3>
# <br>
# In this exercise we develop a more complete tight-binding model for graphene by considering a set of four atomic orbitals per carbon site. We still restrict the interactions to the nearest-neighbours. Again, the values of the parameters are set to ensure a reasonable agreement with experiments.
# <br><br>
# - What do you observe? Can you locate the Dirac cones? Why are there more bands?
# <br><br>
# - Does this calculation valide the $\pi$-band approximation for the description of the low energy electronic properties of graphene?

# %%
# Define the atoms
carbon = tb.NumericalAtom('C','C',orbs=['s','px','py','pz'])
atomictable = tb.AtomicTable(carbon)

# Build the structure
lattice = tb.Lattice.from_parameters(2.46,2.46,20.,90.,90.,60.)
pos = [[0.,0.,0.],[1./3,1./3,0.]]
struct = tb.Structure(lattice, ['C','C'], pos, coords_are_cartesian=False)

# Define the interatomic interactions
graph = tb.StructureGraph.init_from_structure(struct, 1.45)
sk = tb.SlaterKosterParams(atomictable, spinpol=False, spinorb=False)
sk.set_local_integrals([('C', 0, 0, -4.25956174899)])
sk.set_local_integrals([('C', 1, 1,  0.0476436867717)])
sk.set_local_integrals([('C', 2, 2,  0.0476436867717)])
sk.set_local_integrals([('C', 3, 3,  0.0476436867717)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 0,  4.99016309759)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 1,  4.93523388607)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 2, -4.06687028938)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 3,  2.61251108391)])


# Compute the interatomic integrals
egraph = tb.ElectronicStructure(graph, atomictable, H=sk)
egraph.compute_integrals('H')

# Define the high-symmetry path in the Brillouin zone
kbands = [[0.,0.,0.],[0.5,0.,0.],\
          [0.5,0.,0.],[2./3.,1./3.,0.],\
          [2./3.,1./3.,0.],[0.,0.,0.]]
nkpts = [50,50,50]
bands = egraph.bands_structure(include=['H'], lines=kbands, nkpts=nkpts)

# Plot the bands structure
bands.plot_bands(xscale=True, klabels=['$\Gamma$','M','K','$\Gamma$'], \
                 vertices=[0,49,100,150], spincolors=['blue'],linestyle='-')

plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/supertb/eigenset.py:671: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabels)

# %% [markdown]
# <h3>Exercise 2c: <br><br>Compute the band structure of graphene including interactions up to the second-nearest neighbours</h3>
# <br>
# In this exercise we come back to our first model with one orbital only per carbon site but we include interactions up to the second-nearest neighbours. The values of the parameters are set to ensure a reasonable agreement with experiments.
# <br><br>
# - What is the main effect of the second nearest neighbours interaction?

# %%
# Define the atoms
carbon = tb.NumericalAtom('C','C',orbs=['pz'])
atomictable = tb.AtomicTable(carbon)

# Build the structure
lattice = tb.Lattice.from_parameters(2.46,2.46,20.,90.,90.,60.)
pos = [[0.,0.,0.],[1./3,1./3,0.]]
struct = tb.Structure(lattice, ['C','C'], pos, coords_are_cartesian=False)

# Define the interatomic interactions
graph = tb.StructureGraph.init_from_structure(struct, 2.6)

def radial_func(hopping,length,hop1=0.,hop2=0.):
    if length<1.45:
        return hop1
    elif length<2.5:
        return hop2
    else:
        return 0.

sk = tb.SlaterKosterParams(atomictable, spinpol=False, spinorb=False, radialf=radial_func)
sk.set_local_integrals([('C', 0, 0, 0.)])
sk.set_non_local_integrals([('C','C', 0, 0, 3, 0., {'hop2': 0.3, 'hop1': 2.6})])

# Compute the interatomic integrals
egraph = tb.ElectronicStructure(graph, atomictable, H=sk)
egraph.compute_integrals('H')

# Define the high-symmetry path in the Brillouin zone
kbands = [[0.,0.,0.],[0.5,0.,0.],\
          [0.5,0.,0.],[2./3.,1./3.,0.],\
          [2./3.,1./3.,0.],[0.,0.,0.]]
nkpts = [50,50,50]
bands = egraph.bands_structure(include=['H'], lines=kbands, nkpts=nkpts)

# Plot the bands structure
bands.plot_bands(xscale=True, klabels=['$\Gamma$','M','K','$\Gamma$'], \
                 vertices=[0,49,100,150], spincolors=['blue'],linestyle='-')

plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/supertb/eigenset.py:671: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabels)

# %% [markdown]
# <h3>Exercise 2d: <br><br>Compute the $\pi$-band structure of hexagonal Boron Nitride </h3>
# <br>
# In this exercise we adapt the model developped previously for graphene so as to get intuition about the band structure of hexagonal Boron Nitride (hBN). Hexagonal boron nitride has the same structure as graphene except that one of the atoms in the unit-cell is Boron and the other is Nitrogen. As a consequence, hBN has a lower symmetry group than graphene. What is the consequence on its band structure?

# %%
# Define the atoms
boron = tb.NumericalAtom('B','B',orbs=['s'])
nitrogen = tb.NumericalAtom('N','N',orbs=['s'])
atomictable = tb.AtomicTable(boron, nitrogen)

# Build the structure
lattice = tb.Lattice.from_parameters(2.46,2.46,20.,90.,90.,60.)
pos = [[0.,0.,0.],[1./3,1./3,0.]]
struct = tb.Structure(lattice, ['B','N'], pos, coords_are_cartesian=False)

# Define the interatomic interactions
graph = tb.StructureGraph.init_from_structure(struct, 1.45)
sk = tb.SlaterKosterParams(atomictable, spinpol=False, spinorb=False)
sk.set_local_integrals([('B', 0, 0, -2.5)])
sk.set_local_integrals([('N', 0, 0, +2.5)])
sk.set_non_local_integrals([('B','N', 0, 0, 0, 2.6)])

# Compute the interatomic integrals
egraph = tb.ElectronicStructure(graph, atomictable, H=sk)
egraph.compute_integrals('H')

# Define the high-symmetry path in the Brillouin zone
kbands = [[0.,0.,0.],[0.5,0.,0.],\
          [0.5,0.,0.],[2./3.,1./3.,0.],\
          [2./3.,1./3.,0.],[0.,0.,0.]]
nkpts = [50,50,50]
bands = egraph.bands_structure(include=['H'], lines=kbands, nkpts=nkpts)

# Plot the bands structure
bands.plot_bands(xscale=True, klabels=['$\Gamma$','M','K','$\Gamma$'], \
                 vertices=[0,49,100,150], spincolors=['blue'],linestyle='-')

plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/supertb/eigenset.py:671: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabels)

# %% [markdown]
# <h3>Exercise 2e: <br><br>Compute the band structure of graphene with a vacancy </h3>
# <br>
# In this exercise we compute the band structure of a graphene supercell. By increasing progressively the size of the supercell we visualize the mechanism of bands folding. By removing a carbon a atom we create a vacancy (or more accurately, a periodic array of vacancies).
# <br><br>
# - Plot the band structures of supercell of various sizes. What do you observe? Is it consistent with the translational symmetry of the lattice in reciprocal space?
# - Create a vacancy in the supercell. What do you observe when you progressively increase the size of the supercell?

# %%
# Import the required python modules
import supertb as tb
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize']=(8,6)

# Define the atoms
carbon = tb.NumericalAtom('C','C',orbs=['s'])
atomictable = tb.AtomicTable(carbon)

# Build the structure
lattice = tb.Lattice.from_parameters(2.46,2.46,20.,90.,90.,60.)
pos = [[0.,0.,0.],[1./3,1./3,0.]]
struct = tb.Structure(lattice, ['C','C'], pos, coords_are_cartesian=False)
struct.make_supercell([4,4,1])
struct.remove_sites([0])


# Define the interatomic interactions
graph = tb.StructureGraph.init_from_structure(struct, 1.45)
sk = tb.SlaterKosterParams(atomictable, spinpol=False, spinorb=False)
sk.set_local_integrals([('C', 0, 0, 0.)])
sk.set_non_local_integrals([('C','C', 0, 0, 0, 2.6)])

# Compute the interatomic integrals
egraph = tb.ElectronicStructure(graph, atomictable, H=sk)
egraph.compute_integrals('H')

# Define the high-symmetry path in the Brillouin zone
kbands = [[0.,0.,0.],[0.5,0.,0.],\
          [0.5,0.,0.],[2./3.,1./3.,0.],\
          [2./3.,1./3.,0.],[0.,0.,0.]]
nkpts = [50,50,50]
bands = egraph.bands_structure(include=['H'], lines=kbands, nkpts=nkpts)

# Plot the bands structure
bands.plot_bands(xscale=True, klabels=['$\Gamma$','M','K','$\Gamma$'], \
                 vertices=[0,49,100,150], spincolors=['blue'],linestyle='-')

plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/supertb/eigenset.py:671: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabels)

# %% [markdown]
# <h2> Part 3: </br> The electronic structure of carbon nanotubes (CNT)</h2>
#
#
# <p>
#     <div class="rblock">
#     <img align='right' src='https://upload.wikimedia.org/wikipedia/commons/3/35/CNTnames.png' height="350" width="350"> <br>
# </div>
#
# <p>
#     <a target="_tab" href="http://en.wikipedia.org/wiki/Carbon_nanotube#Single-walled">Carbon nanotubes</a> are allotropes of carbon with a cylindrical nanostructure. These cylindrical carbon molecules have novel properties that make them potentially useful in many nanotechnology applications, including electronics, optics and other fields of materials science.
# </p>
# <p>
#     "The structure of a SWNT can be conceptualized by wrapping a one-atom-thick layer of graphite called graphene into a seamless cylinder. The way the graphene sheet is wrapped is represented by a pair of indices (n,m). The integers n and m denote the number of unit vectors along two directions in the honeycomb crystal lattice of graphene. If m = 0, the nanotubes are called zigzag nanotubes, and if n = m, the nanotubes are called armchair nanotubes. Otherwise, they are called chiral." (Source <a target="_tab" href="http://en.wikipedia.org/wiki/Carbon_nanotube#Single-walled">Wikipedia</a>).
# </p>
#
# <h3 style="color:#0B69A5;"> Born-von Karman boundary condition</h3>
# <p>
#     Because of the symmetry and unique electronic structure of graphene, the structure of a nanotube strongly affects its electrical properties. For a given (n,m) nanotube, if n = m, the nanotube is metallic; if n − m is a multiple of 3, then the nanotube is semiconducting with a very small band gap, otherwise the nanotube is a moderate semiconductor. Thus all armchair (n = m) nanotubes are metallic, and nanotubes (6,4), (9,1), etc. are semiconducting. This $(n-m=3j)$ rule is of geometrical nature and can be easily understood by means of the band folding approximation. Neglecting the impact of the curvature, a carbon nanotube can be pictured as a planar portion of graphene with periodic boundary condition applied perpendicular to the axe of the tube. The consequence of the applied periodic boundary condition is that the component of the wavevector in that direction is quantized. Only given velues of $\vec{k}_{perp}$ are compatible with the CNT structure. This is the well know <a target="_tab" href="http://en.wikipedia.org/wiki/Born%E2%80%93von_Karman_boundary_condition ">Born von Karman boundary condition</a>.
# </p>
# <img src='pics/CNT_all.png' height="350" width="1150" align="middle"> <br>
#
# <hr />

# %% [markdown]
# <h3>Exercise: <br><br>Compute the band structure of various carbon nanotubes</h3>
# <br>
# In this exercise we compute the band structure of various carbon nanotubes using the same tight-binding model as the one used previously for graphene.
# <br><br>
# - Plot the band structures of various CNTs. Observe the effect of the Born von Karman boundary condition applied along the circular section of the tube.
# - Does your observation support the n-m=3j rule?

# %%
# Import the required python modules
from nt import create_nt

# Define the atoms
carbon = tb.NumericalAtom('C','C',orbs=['s','px','py','pz'])
atomictable = tb.AtomicTable(carbon)

# Build the structure
struct = create_nt(4,2)
print ('# atoms in unit-cell = ', struct.cart_coords.shape[0])
# Out:
# # atoms in unit-cell =  56

# %%
# Define the interatomic interactions
graph = tb.StructureGraph.init_from_structure(struct, 1.45)
sk = tb.SlaterKosterParams(atomictable, spinpol=False, spinorb=False)
sk.set_local_integrals([('C', 0, 0, -4.25956174899)])
sk.set_local_integrals([('C', 1, 1,  0.0476436867717)])
sk.set_local_integrals([('C', 2, 2,  0.0476436867717)])
sk.set_local_integrals([('C', 3, 3,  0.0476436867717)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 0,  4.99016309759)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 1,  4.93523388607)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 2, -4.06687028938)])
sk.set_non_local_integrals([('C', 'C', 0, 0, 3,  2.61251108391)])

# Compute the interatomic integrals
egraph = tb.ElectronicStructure(graph, atomictable, H=sk)
egraph.compute_integrals('H')

# Define the high-symmetry path in the Brillouin zone
kbands = [[0.,0.,0.],[0.5,0.,0.]]
nkpts = [80]
bands = egraph.bands_structure(include=['H'], lines=kbands, nkpts=nkpts)

# %%
# Plot the bands structure
bands.plot_bands(xscale=True, klabels=['$\Gamma$','$M$'], \
                 vertices=[0,80], spincolors=['blue'],linestyle='-',\
                 emin=-2.,emax=2.)

plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/supertb/eigenset.py:671: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(yticklabels)
